# %% [markdown]
# ## Billiards collisions

# %%
# %matplotlib inline

# %% [markdown]
# Bill should be placed inside thin ring which is able to move freely on the table.

# %%
from Body import Body

bill = Body(1., 1, [0., 0.], [0., 0.])
ring = Body(2., 4, [1., 1.], [0., 0.])
pos_b = [bill.pos]

# %%
# Decide if use mass point coordinates or default ones
from collider import *
switch_to_masspoint(bill, ring)

# %%
from run import init_angle
from ploter import plot_bodies
from math import pi
for k in range(10):
	init_angle(bill, ring, k*pi/25)
	plot_bodies(bill, ring)
# Out:
# Pos b1: [-0.  0.]
# Pos b1: [-0.49737977  0.06283368]
# Pos b1: [-0.96350735  0.24738664]
# Pos b1: [-1.36909421  0.54206275]
# Pos b1: [-1.68865585  0.92834641]
# Pos b1: [-1.90211303  1.38196601]
# Warning: Angle over limit! 0.7539822368615503
# Pos b1: [-1.99605346  1.87441896]
# Warning: Angle over limit! 0.8796459430051421
# Pos b1: [-1.9645745   2.37476263]
# Warning: Angle over limit! 1.0053096491487339
# Pos b1: [-1.8096541   2.85155858]
# Warning: Angle over limit! 1.1309733552923256
# Pos b1: [-1.54102649  3.27484798]

# %%
plt.plot(*zip(*pos_b))
plt.axis('equal')
plt.show()
pos_b = []
